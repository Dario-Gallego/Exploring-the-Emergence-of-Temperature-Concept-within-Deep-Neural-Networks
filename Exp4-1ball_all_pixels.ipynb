# %% [markdown]
# # From optical flow to temperature

# %% [markdown]
# ### Initial imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
from tqdm import tqdm
from glob import glob
from sklearn.model_selection import train_test_split

import keras
from keras.layers import Input, Flatten, Dense
from keras.models import Model
from keras.callbacks import EarlyStopping
import keras.backend as K

# %% [markdown]
# ### Loading images

# %%
data_path = "data/1ball/"

X1 = []
for i in tqdm(glob(data_path + "Input/image1_*.png")):
    im = cv2.imread(i, cv2.IMREAD_GRAYSCALE)
    im = keras.utils.img_to_array(im)
    X1.append(im)
X1 = np.array(X1, dtype="float32") / 255

X2 = []
for i in tqdm(glob(data_path + "Input/image2_*.png")):
    im = cv2.imread(i, cv2.IMREAD_GRAYSCALE)
    im = keras.utils.img_to_array(im)
    X2.append(im)
X2 = np.array(X2, dtype="float32") / 255
# Out:
# 100%|██████████| 10000/10000 [00:01<00:00, 5672.67it/s]
# 100%|██████████| 10000/10000 [00:01<00:00, 5144.22it/s]

# %% [markdown]
# ### Generation of synthetic optical flow
#
# For both frames we obtain the pixels where the ball is present and store them in a list. This list will serve us to know the pixels where we need to assign the velocity vector and also to compute the velocity vector, by using the central pixel (mean of pixels) of the ball.
#
# Additionally, we compute the temperature of the system, as the speed of the ball (in this case we only have one ball), that we will try to predict later.

# %%
# Dataset dependant parameters
num_systems = 10000
pix = 32

# Initialization of the needed data
optical_flow = np.zeros((num_systems, pix, pix, 2))
temperature = np.zeros((num_systems))

# For each system we compute the optical flow and temperature
for i in tqdm(range(num_systems)):
    # Pixels to assign the optical flow
    non_white_pixels_t0 = []
    # Ball region pixels in first frame
    non_white_x_t0 = []
    non_white_y_t0 = []
    # Ball region pixels in second frame
    non_white_x_t1 = []
    non_white_y_t1 = []
    for j in range(pix):
        for k in range(pix):
            # Check if there's ball in that pixel (first frame)
            if X1[i,j,k] != 1:
                non_white_pixels_t0.append((j, k))
                if j not in non_white_y_t0: non_white_y_t0.append(j)
                if k not in non_white_x_t0: non_white_x_t0.append(k)

            # Check if there's ball in that pixel (second frame)
            if X2[i,j,k] != 1:
                if j not in non_white_y_t1: non_white_y_t1.append(j)
                if k not in non_white_x_t1: non_white_x_t1.append(k)
    
    # Compute the vectors and divide by 4 to have (or close to have) them between -1 and 1
    velocity_vector = (np.mean(non_white_x_t1) - np.mean(non_white_x_t0)) / 4, (np.mean(non_white_y_t1) - np.mean(non_white_y_t0)) / 4
    # Compute temperature value
    temperature[i] = np.sqrt(velocity_vector[0]**2 + velocity_vector[1]**2)

    # Assign optical flow to ball pixels
    for j, k in non_white_pixels_t0:
        optical_flow[i, j, k] = velocity_vector
# Out:
# 100%|██████████| 10000/10000 [00:32<00:00, 304.91it/s]

# %% [markdown]
# Here we print (from left to right) the two frames of the sample, a 3rd image with both balls (black for first frame and purple for second frame) to see the movement, and a 4th image with the synthetic optical flow.

# %%
for i in range(5):
    plt.figure(figsize=(20, 5))

    plt.subplot(141)
    plt.title('Frame 1')
    plt.imshow(X1[i], cmap='gray')

    plt.subplot(142)
    plt.title('Frame 2')
    plt.imshow(X2[i], cmap='gray')

    plt.subplot(143)
    plt.title('Both frames')
    plt.imshow(X1[i], cmap='gray')
    plt.imshow(X2[i], alpha=0.5)

    plt.subplot(144)
    plt.ylim(32, 0)
    plt.title('Optical Flow')
    plt.quiver(optical_flow[i, ::1, ::1, 0], optical_flow[i, ::1, ::1, 1],
            angles='xy',            # use 'xy' angles for consistent arrow orientation
            scale_units='xy',       # use 'xy' scale units for consistent arrow length
            scale=0.2)

    plt.show()

plt.close()

# %% [markdown]
# ### Model definition and training

# %%
def model(input_shape):
   inputs = Input(shape=input_shape)

   x = Flatten()(inputs)

   x = Dense(64, activation="relu")(x)
   x = Dense(2)(x)
   outputs = Dense(1)(x)
    
   model = Model(inputs=inputs, outputs=outputs)
   return model

model = model((pix, pix, 2))

model.summary()

# Free up RAM in case the model definition cells were run multiple times
K.clear_session()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 2)]       0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 64)                131136
#
#  dense_1 (Dense)             (None, 2)                 130
#
#  dense_2 (Dense)             (None, 1)                 3
#
# =================================================================
# Total params: 131,269
# Trainable params: 131,269
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train-val-test split (80-10-10)
x_train, x_test, y_train, y_test = train_test_split(optical_flow, temperature, test_size=0.2)
x_val, x_test, y_val, y_test = train_test_split(x_test, y_test, test_size=0.5)

# Compile the model
optimizer = keras.optimizers.Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='mae')

# Fit the model
model.fit(x_train, y_train,
          epochs=250,
          batch_size=16,
          shuffle=True,
          validation_data=(x_val, y_val),
          callbacks=[EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, min_delta = 0.0001)])
# Out:
# Epoch 1/250
# 500/500 [==============================] - 3s 4ms/step - loss: 0.0725 - val_loss: 0.0423
# Epoch 2/250
# 500/500 [==============================] - 1s 3ms/step - loss: 0.0324 - val_loss: 0.0302
# Epoch 3/250
# 500/500 [==============================] - 2s 3ms/step - loss: 0.0258 - val_loss: 0.0245
# Epoch 4/250
# 500/500 [==============================] - 1s 3ms/step - loss: 0.0228 - val_loss: 0.0213
# Epoch 5/250
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0202 - val_loss: 0.0197
# Epoch 6/250
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0191 - val_loss: 0.0187
# Epoch 7/250
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0181 - val_loss: 0.0205
# Epoch 8/250
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0171 - val_loss: 0.0197
# Epoch 9/250
# 500/500 [==============================] - 1s 3ms/step - loss: 0.0161 - val_loss: 0.0171
# Epoch 10/250
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0158 - val_loss: 0.0187
# Epoch 11/250
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0156 - val_loss: 0.0141
# Epoch 12/250
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0142 - val_loss: 0.0153
# Epoch 13/250
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0143 - val_loss: 0.0136
# Epoch 14/250
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0136 - val_loss: 0.0136
# Epoch 15/250
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0134 - val_loss: 0.0151
# Epoch 16/250
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0128 - val_loss: 0.0122
# Epoch 17/250
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0129 - val_loss: 0.0116
# Epoch 18/250
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0123 - val_loss: 0.0118
# Epoch 19/250
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0121 - val_loss: 0.0135
# Epoch 20/250
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0122 - val_loss: 0.0124
# Epoch 21/250
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0116 - val_loss: 0.0120
# Epoch 22/250
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0115 - val_loss: 0.0113
# Epoch 23/250
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0113 - val_loss: 0.0114
# Epoch 24/250
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0109 - val_loss: 0.0111
# Epoch 25/250
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0109 - val_loss: 0.0114
# Epoch 26/250
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0106 - val_loss: 0.0109
# Epoch 27/250
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0102 - val_loss: 0.0120
# Epoch 28/250
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0103 - val_loss: 0.0117
# Epoch 29/250
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0099 - val_loss: 0.0100
# Epoch 30/250
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0102 - val_loss: 0.0107
# Epoch 31/250
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0100 - val_loss: 0.0106
# Epoch 32/250
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0098 - val_loss: 0.0093
# Epoch 33/250
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0096 - val_loss: 0.0106
# Epoch 34/250
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0094 - val_loss: 0.0095
# Epoch 35/250
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0089 - val_loss: 0.0098
# Epoch 36/250
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0087 - val_loss: 0.0098
# Epoch 37/250
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0089 - val_loss: 0.0109
# Epoch 38/250
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0088 - val_loss: 0.0105
# Epoch 39/250
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0090 - val_loss: 0.0094
# Epoch 40/250
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0092 - val_loss: 0.0090
# Epoch 41/250
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0086 - val_loss: 0.0094
# Epoch 42/250
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0086 - val_loss: 0.0094
# Epoch 43/250
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0083 - val_loss: 0.0085
# Epoch 44/250
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0085 - val_loss: 0.0107
# Epoch 45/250
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0083 - val_loss: 0.0081
# Epoch 46/250
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0082 - val_loss: 0.0088
# Epoch 47/250
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0085 - val_loss: 0.0085
# Epoch 48/250
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0078 - val_loss: 0.0081
# Epoch 49/250
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0078 - val_loss: 0.0079
# Epoch 50/250
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0078 - val_loss: 0.0078
# Epoch 51/250
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0078 - val_loss: 0.0080
# Epoch 52/250
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0077 - val_loss: 0.0082
# Epoch 53/250
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0077 - val_loss: 0.0082
# Epoch 54/250
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0075 - val_loss: 0.0110
# Epoch 55/250
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0075 - val_loss: 0.0075
# Epoch 56/250
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0075 - val_loss: 0.0081
# Epoch 57/250
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0075 - val_loss: 0.0077
# Epoch 58/250
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0076 - val_loss: 0.0103
# Epoch 59/250
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0075 - val_loss: 0.0070
# Epoch 60/250
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0072 - val_loss: 0.0087
# Epoch 61/250
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0073 - val_loss: 0.0084
# Epoch 62/250
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0073 - val_loss: 0.0073
# Epoch 63/250
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0070 - val_loss: 0.0082
# Epoch 64/250
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0073 - val_loss: 0.0076
# Epoch 65/250
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0069 - val_loss: 0.0072
# Epoch 66/250
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0069 - val_loss: 0.0081
# Epoch 67/250
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0069 - val_loss: 0.0084
# Epoch 68/250
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0070 - val_loss: 0.0075
# Epoch 69/250
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0070 - val_loss: 0.0079

# %% [markdown]
# ### Model results

# %%
predictions = model.predict(x_test)

for i in range(5):
    print(str(i) + '\nPrediction: ' + str(predictions[i]) + '\nActual temperature: ' + str(y_test[i]))
# Out:
# 32/32 [==============================] - 0s 1ms/step
# 0
# Prediction: [0.89803827]
# Actual temperature: 0.9013878188659973
# 1
# Prediction: [0.90585214]
# Actual temperature: 0.9013878188659973
# 2
# Prediction: [0.55040514]
# Actual temperature: 0.5590169943749475
# 3
# Prediction: [0.25324288]
# Actual temperature: 0.25
# 4
# Prediction: [0.35659608]
# Actual temperature: 0.3535533905932738

# %% [markdown]
# We can see that the results are great, with slight errors in the majority of predictions.
